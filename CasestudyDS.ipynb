# %%
import pandas as pd

# %%
df=pd.read_excel('payroll_dataset.xlsx', sheet_name ='Employees')
df1=pd.read_excel('payroll_dataset.xlsx', sheet_name ='Departments')

# %%
# Merging the Employees and Departments tables and displaying the first 5 rows of the merged dataset.

# %%
merged=pd.merge(df,df1, on='DepartmentID')

# %%
merged
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate  Location  \
# 0            1    Employee 1         D001    6000  2020-01-31  New York
# 1            5    Employee 5         D001    6400  2020-05-31  New York
# 2            9    Employee 9         D001    6800  2020-09-30  New York
# 3           13   Employee 13         D001    7200  2021-01-31  New York
# 4           17   Employee 17         D001    7600  2021-05-31  New York
# ..         ...           ...          ...     ...         ...       ...
# 95          84   Employee 84         D004   14300  2026-12-31   Houston
# 96          88   Employee 88         D004   14700  2027-04-30   Houston
# 97          92   Employee 92         D004   15100  2027-08-31   Houston
# 98          96   Employee 96         D004   15500  2027-12-31   Houston
# 99         100  Employee 100         D004   15900  2028-04-30   Houston
#
#    DepartmentName
# 0              IT
# 1              IT
# 2              IT
# 3              IT
# ...

# %%
merged.head()
# Out:
#    EmployeeID         Name DepartmentID  Salary    HireDate  Location  \
# 0           1   Employee 1         D001    6000  2020-01-31  New York
# 1           5   Employee 5         D001    6400  2020-05-31  New York
# 2           9   Employee 9         D001    6800  2020-09-30  New York
# 3          13  Employee 13         D001    7200  2021-01-31  New York
# 4          17  Employee 17         D001    7600  2021-05-31  New York
#
#   DepartmentName
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT

# %%
# Removing duplicate records from the dataset.

# %%
merged_no_duplicates=merged.drop_duplicates()
merged_no_duplicates
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate  Location  \
# 0            1    Employee 1         D001    6000  2020-01-31  New York
# 1            5    Employee 5         D001    6400  2020-05-31  New York
# 2            9    Employee 9         D001    6800  2020-09-30  New York
# 3           13   Employee 13         D001    7200  2021-01-31  New York
# 4           17   Employee 17         D001    7600  2021-05-31  New York
# ..         ...           ...          ...     ...         ...       ...
# 95          84   Employee 84         D004   14300  2026-12-31   Houston
# 96          88   Employee 88         D004   14700  2027-04-30   Houston
# 97          92   Employee 92         D004   15100  2027-08-31   Houston
# 98          96   Employee 96         D004   15500  2027-12-31   Houston
# 99         100  Employee 100         D004   15900  2028-04-30   Houston
#
#    DepartmentName
# 0              IT
# 1              IT
# 2              IT
# 3              IT
# ...

# %%
#The interquartile range (IQR) method to detect and handle outliers in the Salary column.

# %%
Q1=df['Salary'].quantile(0.25)

# %%
Q3=df['Salary'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
ib=Q1-1.5*IQR

# %%
ub=Q3+1.5*IQR

# %%
outlier=((df[['Salary']]<ib) | (df[['Salary']]>ub)).any(axis=1)

# %%
cleaned=df[~outlier]

# %%
cleaned
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate     Location
# 0            1    Employee 1         D001    6000  2020-01-31     New York
# 1            2    Employee 2         D002    6100  2020-02-29  Los Angeles
# 2            3    Employee 3         D003    6200  2020-03-31      Chicago
# 3            4    Employee 4         D004    6300  2020-04-30      Houston
# 4            5    Employee 5         D001    6400  2020-05-31     New York
# ..         ...           ...          ...     ...         ...          ...
# 95          96   Employee 96         D004   15500  2027-12-31      Houston
# 96          97   Employee 97         D001   15600  2028-01-31     New York
# 97          98   Employee 98         D002   15700  2028-02-29  Los Angeles
# 98          99   Employee 99         D003   15800  2028-03-31      Chicago
# 99         100  Employee 100         D004   15900  2028-04-30      Houston
#
# [100 rows x 6 columns]

# %%
# Min-Max normalization on the Salary column and display the transformed dataset.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
df['Salary_Normalized'] = scaler.fit_transform(df[['Salary']])

# %%
df
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate     Location  \
# 0            1    Employee 1         D001    6000  2020-01-31     New York
# 1            2    Employee 2         D002    6100  2020-02-29  Los Angeles
# 2            3    Employee 3         D003    6200  2020-03-31      Chicago
# 3            4    Employee 4         D004    6300  2020-04-30      Houston
# 4            5    Employee 5         D001    6400  2020-05-31     New York
# ..         ...           ...          ...     ...         ...          ...
# 95          96   Employee 96         D004   15500  2027-12-31      Houston
# 96          97   Employee 97         D001   15600  2028-01-31     New York
# 97          98   Employee 98         D002   15700  2028-02-29  Los Angeles
# 98          99   Employee 99         D003   15800  2028-03-31      Chicago
# 99         100  Employee 100         D004   15900  2028-04-30      Houston
#
#     Salary_Normalized
# 0            0.000000
# ...

# %%
# One-hot encoding to the Location column and show the updated dataset.

# %%
df_encoded = pd.get_dummies(df, columns=['Location'])

# %%
df_encoded
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate  \
# 0            1    Employee 1         D001    6000  2020-01-31
# 1            2    Employee 2         D002    6100  2020-02-29
# 2            3    Employee 3         D003    6200  2020-03-31
# 3            4    Employee 4         D004    6300  2020-04-30
# 4            5    Employee 5         D001    6400  2020-05-31
# ..         ...           ...          ...     ...         ...
# 95          96   Employee 96         D004   15500  2027-12-31
# 96          97   Employee 97         D001   15600  2028-01-31
# 97          98   Employee 98         D002   15700  2028-02-29
# 98          99   Employee 99         D003   15800  2028-03-31
# 99         100  Employee 100         D004   15900  2028-04-30
#
#     Salary_Normalized  Location_Chicago  Location_Houston  \
# 0            0.000000                 0                 0
# 1            0.010101                 0                 0
# ...
